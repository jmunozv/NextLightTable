# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>
# LIGHT TABLE - USE</p><br>

# %%
from IPython.core.display import HTML
css = open('css/style-table.css').read() + open('css/style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
# General importings
import os
import numpy  as np
import pandas as pd

# Specific IC stuff
import invisible_cities.core.system_of_units  as units

# %% [markdown]
# #### For testing this NB, I'm using the NEW - S1 table generated by me in Harvard cluster

# %%
table_fname = "./data/NEXT_NEW/table/NEXT_NEW.energy.S2.PmtR11410.LightTable.h5"
light_table = pd.read_hdf(table_fname, "LightTable")

# %%
light_table.head()
# Out:
#                PmtR11410_0  PmtR11410_1  PmtR11410_2  PmtR11410_3  \
# x      y
# -8.0   -8.0        0.00033      0.00040      0.00034      0.00017
#         192.0      0.00025      0.00028      0.00028      0.00021
#  192.0 -8.0        0.00019      0.00025      0.00020      0.00025
# -8.0   -8.0        0.00033      0.00040      0.00034      0.00017
#         192.0      0.00025      0.00028      0.00028      0.00021
#
#                PmtR11410_4  PmtR11410_5  PmtR11410_6  PmtR11410_7  \
# x      y
# -8.0   -8.0        0.00022      0.00013      0.00019      0.00015
#         192.0      0.00021      0.00016      0.00032      0.00014
#  192.0 -8.0        0.00011      0.00011      0.00016      0.00014
# -8.0   -8.0        0.00022      0.00013      0.00019      0.00015
#         192.0      0.00021      0.00016      0.00032      0.00014
#
#                PmtR11410_8  PmtR11410_9  PmtR11410_10  PmtR11410_11  \
# x      y
# ...

# %% [markdown]
# ## Behaviour of single PMTs

# %% [markdown]
# #### The behaviour of the first 3 PMTs is similar

# %%
light_table.hist('PmtR11410_0', bins=20)
light_table.PmtR11410_0.describe()
# Out:
# count    6.000000
# mean     0.000257
# std      0.000063
# min      0.000190
# 25%      0.000205
# 50%      0.000250
# 75%      0.000310
# max      0.000330
# Name: PmtR11410_0, dtype: float64

# %% [markdown]
# #### The behaviour of the last 9 PMTs is similar

# %%
light_table.hist('PmtR11410_3', bins=20)
light_table.PmtR11410_3.describe()
# Out:
# count    6.000000
# mean     0.000210
# std      0.000036
# min      0.000170
# 25%      0.000180
# 50%      0.000210
# 75%      0.000240
# max      0.000250
# Name: PmtR11410_3, dtype: float64

# %% [markdown]
# ## Total charge distribution per z_slice

# %%
### TO BE IMPLEMENTED

# %% [markdown]
# ## Accesing data

# %% [markdown]
# #### Accessing the probability of a photon produced at (x,y,z) to be detected by a given PMT

# %%
pos = (-188.0, -88.0, 80.0)
pmt = "PmtR11410_0"

light_table.at[pos, pmt]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda/envs/IC-3.7-2018-10-20/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: -188.0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# Accessing the probability of a photon produced at (x,y,z) to be detected by any of the PMTs

# %%
pos = (-188.0, -88.0, 60.0)
pmt = "PmtR11410_total"

light_table.at[pos, pmt]

# %% [markdown]
# #### Accessing the probabilities of a photon produced at (x,y,z) to be detected

# %%
pos = (-188.0, -88.0, 60.0)

light_table.loc[pos]

# %% [markdown]
# In case you need it in a list (without the total) to be used as a probability distribution ...

# %%
light_table.loc[pos].to_numpy()[:-1]

# %% [markdown]
# #### Getting the nearest indices of a random position to retrieve the appropriate probabilities.
#
# It has to consider:
# * The index are already sorted, so take advance of it.
# * The index could be not equispaced

# %%
# In principle, this info should be got from the configuration table

pitch_x = 20 * units.mm
pitch_y = 20 * units.mm
pitch_z = 20 * units.mm

table_indices_x = light_table.index.get_level_values(0)
table_indices_y = light_table.index.get_level_values(1)
table_indices_z = light_table.index.get_level_values(2)

# %%
### TO BE IMPLEMENTED
